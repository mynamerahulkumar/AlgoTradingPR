# %% [markdown]
# # Trading with python and Binance

# %%
api_key="GiIoRzFwwI6XmvaOCShY21XSZjLPfO8tbyeN1ZMLvfMqD5lW4SzyR44ZsrzZhOVM"
secret_key="7qbFT2xOaSxEW1eSuRsOZ0r5y4wSvVIHbmdoP28VbFEUpyOwC09xxoiaq2SzPBGt"

# %%
from binance.client import Client

# %%
client=Client(api_key=api_key,api_secret=secret_key,tld="com")

# %%
client

# %%
# account details
client.get_account()
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1744020901547,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %% [markdown]
# If you have an account on __Binance.US__ (US residents) <br>
# (If you are using an exchange from the US, Japan or other TLD then make sure pass tld=a when creating the client.)

# %%
client.ping()
# Out:
# {}

# %%
client.get_system_status()
# Out:
# {'status': 0, 'msg': 'normal'}

# %%
account=client.get_account()

# %%
account
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1744020901547,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
account["accountType"]
# Out:
# 'SPOT'

# %%
import pandas as pd

# %%
pd.to_datetime(account["updateTime"],unit="ms") # last update ->UTC time
# Out:
# Timestamp('2025-04-07 10:15:01.547000')

# %%
account["balances"]
# Out:
# [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
df=pd.DataFrame(account["balances"])
df
# Out:
#            asset        free      locked
# 0            BTC  0.00000000  0.00000000
# 1            LTC  0.00000000  0.00000000
# 2            ETH  0.00000000  0.00000000
# 3            NEO  0.00000000  0.00000000
# 4            BNB  0.00000000  0.00000000
# ..           ...         ...         ...
# 658          TUT  0.00000000  0.00000000
# 659  BROCCOLI714  0.00000000  0.00000000
# 660       KERNEL  0.00000000  0.00000000
# 661         BABY  0.00000000  0.00000000
# 662      BIGTIME  0.00000000  0.00000000
#
# [663 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   asset   663 non-null    object
#  1   free    663 non-null    object
#  2   locked  663 non-null    object
# dtypes: object(3)
# memory usage: 15.7+ KB

# %%
df.free=pd.to_numeric(df.free,errors="coerce")
df.locked=pd.to_numeric(df.locked,errors="coerce")

# %%
df.loc[df.free>0]
# Out:
# Empty DataFrame
# Columns: [asset, free, locked]
# Index: []

# %%
client.get_asset_balance(asset="BTC")
# Out:
# {'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'}

# %%
client.get_asset_balance(asset="ETH")
# Out:
# {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'}

# %%
client.get_asset_balance(asset="USDT")
# Out:
# {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'}

# %%
float(client.get_asset_balance(asset="EUR")["free"])
# Out:
# 0.0

# %%
snap=client.get_account_snapshot(type="SPOT")
snap # daily account snapshot
# Out:
# {'code': 200, 'msg': '', 'snapshotVos': []}

# %%
snap=pd.json_normalize(snap["snapshotVos"])
snap
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
snap.updateTime=pd.to_datetime(snap["updateTime"],unit="ms")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 snap.updateTime=pd.to_datetime(snap["updateTime"],unit="ms")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'updateTime'

# %%
snap
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
snap["data.balances"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 snap["data.balances"][0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'data.balances'

# %%
client.get_exchange_info()["rateLimits"] #api limits
# Out:
# [{'rateLimitType': 'REQUEST_WEIGHT',
#   'interval': 'MINUTE',
#   'intervalNum': 1,
#   'limit': 6000},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'SECOND',
#   'intervalNum': 10,
#   'limit': 100},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'DAY',
#   'intervalNum': 1,
#   'limit': 200000},
#  {'rateLimitType': 'RAW_REQUESTS',
#   'interval': 'MINUTE',
#   'intervalNum': 5,
#   'limit': 61000}]

# %%
coins=pd.DataFrame(client.get_all_coins_info())
coins
# Out:
#            coin  depositAllEnable  withdrawAllEnable  \
# 0          AGLD              True               True
# 1          STPT              True               True
# 2           MXN              True               True
# 3           SCR              True               True
# 4    MATICUSDCE              True               True
# ..          ...               ...                ...
# 588        AKRO             False               True
# 589        MOVR              True               True
# 590         XMR             False              False
# 591  1000PEPPER             False               True
# 592        COTI              True               True
#
#                                name free locked freeze withdrawing ipoing  \
# 0                    Adventure Gold    0      0      0           0      0
# 1    Standard Tokenization Protocol    0      0      0           0      0
# 2                      Mexican Peso    0      0      0           0      0
# ...

# %%
coins.loc[coins.coin=="BTC"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable     name free locked freeze  \
# 349  BTC              True               True  Bitcoin    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 349           0      0       0       0         False     True
#
#                                            networkList
# 349  [{'network': 'BSC', 'coin': 'BTC', 'withdrawIn...

# %%
coins.loc[coins.coin=="EUR"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable  name free locked freeze  \
# 269  EUR              True               True  Euro    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 269           0      0       0       0          True     True
#
#                                            networkList
# 269  [{'network': 'FIAT_MONEY', 'coin': 'EUR', 'wit...

# %%
coins.loc[coins.coin=="BTCUSDT"]
# Out:
# Empty DataFrame
# Columns: [coin, depositAllEnable, withdrawAllEnable, name, free, locked, freeze, withdrawing, ipoing, ipoable, storage, isLegalMoney, trading, networkList]
# Index: []

# %%
coins.loc[coins.coin=="USDT"]
# Out:
#      coin  depositAllEnable  withdrawAllEnable      name free locked freeze  \
# 522  USDT              True               True  TetherUS    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 522           0      0       0       0         False     True
#
#                                            networkList
# 522  [{'network': 'BSC', 'coin': 'USDT', 'withdrawI...

# %%
client.get_trade_fee(symbol="BUSDUSDT") #ZERO COMMISION FOR STABLE COIN
# Out:
# [{'symbol': 'BUSDUSDT', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_trade_fee(symbol="BTCEUR") #ZERO COMMISION FOR STABLE COIN
# Out:
# [{'symbol': 'BTCEUR',
#   'makerCommission': '0.001',
#   'takerCommission': '0.00095'}]

# %%
client.get_trade_fee(symbol="BTCUSD") #ZERO COMMISION FOR STABLE COIN
# Out:
# []

# %%
client.get_symbol_info(symbol="BTCEUR")
# Out:
# {'symbol': 'BTCEUR',
#  'status': 'TRADING',
#  'baseAsset': 'BTC',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'EUR',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'otoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': False,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00001000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00001000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
# ...

# %%
client.get_symbol_info(symbol="BTCINR")

# %%
client.get_symbol_info(symbol="BTCUSD")

# %% [markdown]
# # GETTING MARKET DATA

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %% [markdown]
# ## CURRENT PRICES

# %%
client.get_symbol_ticker(symbol="BTCUSDT") # current price for one symbol
# Out:
# {'symbol': 'BTCUSDT', 'price': '84940.50000000'}

# %%
float(client.get_symbol_ticker(symbol="BTCUSDT")["price"])
# Out:
# 84934.0

# %%
client.get_avg_price(symbol="BTCUSDT") # CURRENT AVG PRICE
# Out:
# {'mins': 5, 'price': '84925.82921313', 'closeTime': 1744660394312}

# %%
float(client.get_symbol_ticker(symbol = "BTCEUR")["price"])
# Out:
# 74795.41

# %%
# get current prices for all pairs
prices=client.get_all_tickers()

# %%
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.01925000'},
#  {'symbol': 'LTCBTC', 'price': '0.00090700'},
#  {'symbol': 'BNBBTC', 'price': '0.00691900'},
#  {'symbol': 'NEOBTC', 'price': '0.00006230'},
#  {'symbol': 'QTUMETH', 'price': '0.00120500'},
#  {'symbol': 'EOSETH', 'price': '0.00037730'},
#  {'symbol': 'SNTETH', 'price': '0.00001157'},
#  {'symbol': 'BNTETH', 'price': '0.00020260'},
#  {'symbol': 'BCCBTC', 'price': '0.00000000'},
#  {'symbol': 'GASBTC', 'price': '0.00003280'},
#  {'symbol': 'BNBETH', 'price': '0.35950000'},
#  {'symbol': 'BTCUSDT', 'price': '84936.12000000'},
#  {'symbol': 'ETHUSDT', 'price': '1634.96000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00000000'},
#  {'symbol': 'OAXETH', 'price': '0.00000000'},
#  {'symbol': 'DNTETH', 'price': '0.00000000'},
#  {'symbol': 'MCOETH', 'price': '0.00000000'},
#  {'symbol': 'ICNETH', 'price': '0.00000000'},
#  {'symbol': 'MCOBTC', 'price': '0.00000000'},
#  {'symbol': 'WTCBTC', 'price': '0.00000024'},
# ...

# %%
df=pd.DataFrame(prices)
df
# Out:
#            symbol        price
# 0          ETHBTC   0.01925000
# 1          LTCBTC   0.00090700
# 2          BNBBTC   0.00691900
# 3          NEOBTC   0.00006230
# 4         QTUMETH   0.00120500
# ...           ...          ...
# 3053    KERNELBNB   0.00055110
# 3054  KERNELFDUSD   0.32320000
# 3055    KERNELTRY  12.26000000
# 3056   KERNELUSDC   0.32260000
# 3057   KERNELUSDT   0.32210000
#
# [3058 rows x 2 columns]

# %%
df[df.symbol.str.contains("ETH")]
# Out:
#        symbol             price
# 0      ETHBTC        0.01925000
# 4     QTUMETH        0.00120500
# 5      EOSETH        0.00037730
# 6      SNTETH        0.00001157
# 7      BNTETH        0.00020260
# ...       ...               ...
# 2684   ETHARS  2054247.00000000
# 2730   POLETH        0.00011220
# 2789  ETHEURI     1439.65000000
# 2899     SETH        0.00030390
# 2955   ETHMXN    32904.00000000
#
# [270 rows x 2 columns]

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("USD")]
# Out:
#            symbol           price
# 11        BTCUSDT  84936.12000000
# 312       BTCTUSD  85059.71000000
# 313       TUSDBTC      0.00000000
# 417       BTCUSDC  84936.39000000
# 454       BTCUSDS      0.00000000
# 614       BTCBUSD  42769.40000000
# 795     BTCUPUSDT     16.60000000
# 796   BTCDOWNUSDT      0.00118500
# 1190      SUSDBTC      0.00000000
# 1240    BTCSTBUSD      1.16000000
# 1241    BTCSTUSDT      5.35000000
# 1621      BTCUSDP  19435.03000000
# 2070     WBTCBUSD  40760.13000000
# 2198     WBTCUSDT  84842.01000000
# 2268     BTCFDUSD  85139.54000000

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("EUR")]
# Out:
#        symbol           price
# 689    BTCEUR  74800.14000000
# 2376  BTCAEUR  51466.50000000
# 2747  BTCEURI  74795.24000000

# %% [markdown]
# ## last 24 hour price change stastitics

# %%
last24=client.get_ticker(symbol="BTCUSDT")
last24
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '927.59000000',
#  'priceChangePercent': '1.105',
#  'weightedAvgPrice': '84628.62732027',
#  'prevClosePrice': '83928.06000000',
#  'lastPrice': '84855.66000000',
#  'lastQty': '0.00276000',
#  'bidPrice': '84855.66000000',
#  'bidQty': '2.08463000',
#  'askPrice': '84855.67000000',
#  'askQty': '1.71976000',
#  'openPrice': '83928.07000000',
#  'highPrice': '85799.99000000',
#  'lowPrice': '83034.23000000',
#  'volume': '30004.95753000',
#  'quoteVolume': '2539278368.56687410',
#  'openTime': 1744574192003,
#  'closeTime': 1744660592003,
#  'firstId': 4821273730,
#  'lastId': 4825589544,
#  'count': 4315815}

# %%
last24["openTime"]
# Out:
# 1744574192003

# %%
pd.to_datetime(last24["openTime"],unit="ms")
# Out:
# Timestamp('2025-04-13 19:56:32.003000')

# %%
pd.to_datetime(last24["closeTime"],unit="ms")
# Out:
# Timestamp('2025-04-14 19:56:32.003000')

# %%
open_price=float(last24["openPrice"])
open_price
# Out:
# 83928.07

# %%
close_price=float(last24["lastPrice"])
close_price
# Out:
# 84855.66

# %%
high_price=float(last24["highPrice"])
high_price
# Out:
# 85799.99

# %%
low_price=float(last24["lowPrice"])
low_price
# Out:
# 83034.23

# %%
float(client.get_symbol_ticker(symbol="BTCUSDT")["price"]) # current price for one symbol
# Out:
# 84904.0

# %%
close_price-open_price
# Out:
# 927.5899999999965

# %%
(close_price/open_price-1)*100
# Out:
# 1.1052202201242034
